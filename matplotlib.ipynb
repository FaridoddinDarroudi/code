# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# FUNCTIONAL 
plt.plot(x,y)
plt.xlabel('X label')
plt.ylabel('y label')
plt.title('Title')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
# OOP Method
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5, 1.0, 'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')

axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5, 1.0, 'SMALLER PLOT')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# for current_ax in axes:
#     current_ax.plot(x,y)
axes[0].plot(x,y)
axes[0].set_title('first plot')

axes[1].plot(y,x)
axes[1].set_title('second plot')

plt.tight_layout() #always put it at the end of the code to prevent overlaping

# %%
axes  # it is a list so we can iterate through it
# Out:
# array([<AxesSubplot: title={'center': 'first plot'}>,
#        <AxesSubplot: title={'center': 'second plot'}>], dtype=object)

# %% [markdown]
# ## Figure Size and SPI

# %%
fig = plt.figure() 

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title('Title')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
fig, axes = plt.subplots(nrows=2,ncols=1,figsize=(8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %%
# saving a figure
fig.savefig('my_picture.png',dpi=200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='X Squered')
ax.plot(x,x**3,label='X Cubed')

ax.legend(loc=(0.1,0.1))

# %% [markdown]
# ## Line and marker style

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='#FF8C00',lw=3,ls='-',marker='o',markersize=15,
       markerfacecolor='yellow',markeredgewidth=3,
        markeredgecolor='green') # RGB Hex Code
# ax.plot(x,y,color='#orange')

# %% [markdown]
# **To change the line width, we can use the linewidth or lw keyword argument. The line style can be selected using the linestyle or ls keyword argument:**

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.5)
ax.plot(x, x+3, color="red", linewidth=1)
ax.plot(x, x+4, color="red", linewidth=2)

# poossible linestyle options '-', '-.', ':', 'steps'
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.5)
line.set_dashes([5,10,15,10]) # format: line length, space length, ...

# possible marker symboles: marker = '+', 'o', '*', 's', ',', '.', '1','2','3'
ax.plot(x, x+9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8,
       markerfacecolor='yellow')
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8,
       markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green')

# %% [markdown]
# ### control over axis appearance
# **In this section we will look at controlling axis sizing properties in a matplotlib figure**

# %% [markdown]
# ## Plot range
# **We can configure the ranges of the axes using the set_ylim and x_lim methods in the axis object, or axis('tight') for automatically getting "tightly fitted axes ranges"**

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y,color='purple', lw=2, ls='--')

ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0.0, 2.0)

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
plt.scatter(x,x**2,lw=2)
